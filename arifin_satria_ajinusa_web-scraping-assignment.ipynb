# %% [markdown]
# # web scrapping AJINUSA

# %% [markdown]
# #Scrapping using Beautifulsoup

# %%
from bs4 import BeautifulSoup
import pandas as pd
import requests

# %% [markdown]
# # antara news

# %%
url = 'https://www.antaranews.com/top-news'

response = requests.get(url)

# %%
soup = BeautifulSoup(response.text,'html.parser')
# soup

# %%
# list_content = soup.select('.m-table-kurs') #bca kurs
# list_content = soup.select('body') #bca kurs
list_content = soup.select('.wrapper__list__article') # antara
# list_content = soup.select('article')

# %%
len(list_content)
# Out:
# 7

# %%
list_content[0]
# list_content
# Out:
# <div class="wrapper__list__article">
# <h1 class="border_section"><a href="https://www.antaranews.com/top-news" title="Top News">Top News</a></h1>
# <div class="card__post card__post-list card__post__transition mt-30">
# <div class="row">
# <div class="col-md-5">
# <div class="card__post__transition position-relative">
# <a href="https://www.antaranews.com/berita/4476701/menkum-ri-tegaskan-ibu-kota-masih-di-daerah-khusus-ibu-kota-jakarta" title="Menkum RI tegaskan ibu kota masih di Daerah Khusus Ibu Kota Jakarta">
# <picture>
# <source data-srcset="https://cdn.antaranews.com/cache/350x233/2024/11/19/IMG-20241118-WA0003_1.jpg.webp" type="image/webp"/>
# <img alt="Menkum RI tegaskan ibu kota masih di Daerah Khusus Ibu Kota Jakarta" class="img-fluid lazyload" data-src="https://cdn.antaranews.com/cache/350x233/2024/11/19/IMG-20241118-WA0003_1.jpg" height="233px" width="350px">
# </img></picture>
# </a>
# </div>
# </div>
# <div class="col-md-7">
# <div class="card__post__body">
# <div class="card__post__content">
# <div class="card__post__title">
# <h2 class="post_title post_title_medium"><a href="https://www.antaranews.com/berita/4476701/menkum-ri-tegaskan-ibu-kota-masih-di-daerah-khusus-ibu-kota-jakarta" title="Menkum RI tegaskan ibu kota masih di Daerah Khusus Ibu Kota Jakarta">Menkum RI tegaskan ibu kota masih di Daerah Khusus Ibu Kota Jakarta</a></h2>
# </div>
# <div class="card__post__author-info mb-2">
# <ul class="list-inline">
# <li class="list-inline-item">
# <span class="text-secondary">18 menit lalu</span>
# </li>
# </ul>
# </div>
# <p>Menteri Hukum RI Supratman Andi Agtas menegaskan kembali bahwa ibu kota negara Indonesia saat ini masih berkedudukan di ...</p>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="card__post card__post-list card__post__transition mt-30">
# <div class="row">
# <div class="col-md-5">
# <div class="card__post__transition position-relative">
# <a href="https://www.antaranews.com/berita/4476537/prabowo-di-g20-makan-bergizi-gratis-bagian-vital-strategi-pemerintah" title="Prabowo di G20: Makan bergizi gratis bagian vital strategi pemerintah">
# <picture>
# <source data-srcset="https://cdn.antaranews.com/cache/350x233/2024/11/19/WhatsApp-Image-2024-11-19-at-12.09.41_1.jpeg.webp" type="image/webp"/>
# <img alt="Prabowo di G20: Makan bergizi gratis bagian vital strategi pemerintah" class="img-fluid lazyload" data-src="https://cdn.antaranews.com/cache/350x233/2024/11/19/WhatsApp-Image-2024-11-19-at-12.09.41_1.jpeg" height="233px" width="350px">
# </img></picture>
# </a>
# </div>
# </div>
# <div class="col-md-7">
# <div class="card__post__body">
# <div class="card__post__content">
# <div class="card__post__title">
# <h2 class="post_title post_title_medium"><a href="https://www.antaranews.com/berita/4476537/prabowo-di-g20-makan-bergizi-gratis-bagian-vital-strategi-pemerintah" title="Prabowo di G20: Makan bergizi gratis bagian vital strategi pemerintah">Prabowo di G20: Makan bergizi gratis bagian vital strategi pemerintah</a></h2>
# </div>
# <div class="card__post__author-info mb-2">
# <ul class="list-inline">
# <li class="list-inline-item">
# <span class="text-secondary">1 jam lalu</span>
# </li>
# </ul>
# </div>
# <p>Presiden Prabowo Subianto menekankan program makan bergizi gratis bagi anak-anak merupakan bagian vital atau sangat ...</p>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="card__post card__post-list card__post__transition mt-30">
# <div class="row">
# <div class="col-md-5">
# <div class="card__post__transition position-relative">
# <a href="https://www.antaranews.com/berita/4476529/kasus-judol-libatkan-komdigi-jumlah-tersangka-jadi-23-orang" title="Kasus judol libatkan Komdigi, jumlah tersangka jadi 23 orang">
# <picture>
# <source data-srcset="https://cdn.antaranews.com/cache/350x233/2024/11/19/1000248458_1.jpg.webp" type="image/webp"/>
# <img alt="Kasus judol libatkan Komdigi, jumlah tersangka jadi 23 orang" class="img-fluid lazyload" data-src="https://cdn.antaranews.com/cache/350x233/2024/11/19/1000248458_1.jpg" height="233px" width="350px"/>
# </picture>
# </a>
# </div>
# </div>
# <div class="col-md-7">
# <div class="card__post__body">
# <div class="card__post__content">
# <div class="card__post__title">
# <h2 class="post_title post_title_medium"><a href="https://www.antaranews.com/berita/4476529/kasus-judol-libatkan-komdigi-jumlah-tersangka-jadi-23-orang" title="Kasus judol libatkan Komdigi, jumlah tersangka jadi 23 orang">Kasus judol libatkan Komdigi, jumlah tersangka jadi 23 orang</a></h2>
# </div>
# <div class="card__post__author-info mb-2">
# <ul class="list-inline">
# <li class="list-inline-item">
# <span class="text-secondary">1 jam lalu</span>
# </li>
# </ul>
# </div>
# <p>Jumlah tersangka kasus judi daring (online/judol) yang melibatkan oknum pegawai Kementerian Komunikasi dan Digital ...</p>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="card__post card__post-list card__post__transition mt-30">
# <div class="row">
# <div class="col-md-5">
# <div class="card__post__transition position-relative">
# <a href="https://www.antaranews.com/berita/4476305/mensos-ri-ingatkan-bantuan-tunai-tidak-digunakan-untuk-judi-online" title="Mensos RI ingatkan bantuan tunai tidak digunakan untuk judi online">
# <picture>
# <source data-srcset="https://cdn.antaranews.com/cache/350x233/2024/11/19/IMG_20241119_111151.jpg.webp" type="image/webp"/>
# <img alt="Mensos RI ingatkan bantuan tunai tidak digunakan untuk judi online" class="img-fluid lazyload" data-src="https://cdn.antaranews.com/cache/350x233/2024/11/19/IMG_20241119_111151.jpg" height="233px" width="350px"/>
# </picture>
# </a>
# </div>
# </div>
# <div class="col-md-7">
# <div class="card__post__body">
# <div class="card__post__content">
# <div class="card__post__title">
# <h2 class="post_title post_title_medium"><a href="https://www.antaranews.com/berita/4476305/mensos-ri-ingatkan-bantuan-tunai-tidak-digunakan-untuk-judi-online" title="Mensos RI ingatkan bantuan tunai tidak digunakan untuk judi online">Mensos RI ingatkan bantuan tunai tidak digunakan untuk judi online</a></h2>
# </div>
# <div class="card__post__author-info mb-2">
# <ul class="list-inline">
# <li class="list-inline-item">
# <span class="text-secondary">3 jam lalu</span>
# </li>
# </ul>
# </div>
# <p>Menteri Sosial RI Saifullah Yusuf mengingatkan agar penerima bantuan sosial (bansos) tunai untuk tidak menyalahgunakan ...</p>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="card__post card__post-list card__post__transition mt-30">
# <div class="row">
# <div class="col-md-5">
# <div class="card__post__transition position-relative">
# <a href="https://www.antaranews.com/berita/4476245/profil-enam-juru-bicara-kantor-komunikasi-kepresidenan" title="Profil enam juru bicara Kantor Komunikasi Kepresidenan">
# <picture>
# <source data-srcset="https://cdn.antaranews.com/cache/350x233/2024/11/19/IMG-20241114-WA0005_copy_2829x2122.jpg.webp" type="image/webp"/>
# <img alt="Profil enam juru bicara Kantor Komunikasi Kepresidenan" class="img-fluid lazyload" data-src="https://cdn.antaranews.com/cache/350x233/2024/11/19/IMG-20241114-WA0005_copy_2829x2122.jpg" height="233px" width="350px"/>
# </picture>
# </a>
# </div>
# </div>
# <div class="col-md-7">
# <div class="card__post__body">
# <div class="card__post__content">
# <div class="card__post__title">
# <h2 class="post_title post_title_medium"><a href="https://www.antaranews.com/berita/4476245/profil-enam-juru-bicara-kantor-komunikasi-kepresidenan" title="Profil enam juru bicara Kantor Komunikasi Kepresidenan">Profil enam juru bicara Kantor Komunikasi Kepresidenan</a></h2>
# </div>
# <div class="card__post__author-info mb-2">
# <ul class="list-inline">
# <li class="list-inline-item">
# <span class="text-secondary">3 jam lalu</span>
# </li>
# </ul>
# </div>
# <p>Kepala Kantor Komunikasi Kepresidenan Hasan Nasbi telah melantik pejabat dan jajaran lembaganya di Gedung Krida Bhakti ...</p>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="card__post card__post-list card__post__transition mt-30">
# <div class="row">
# <div class="col-md-5">
# <div class="card__post__transition position-relative">
# <a href="https://www.antaranews.com/berita/4475977/pratinjau-indonesia-vs-arab-saudi-upaya-menjawab-keraguan" title="Pratinjau Indonesia vs Arab Saudi: upaya menjawab keraguan">
# <picture>
# <source data-srcset="https://cdn.antaranews.com/cache/350x233/2024/11/16/Timnas-Indonesia-kalah-15112024-aaa-2.jpg.webp" type="image/webp"/>
# <img alt="Pratinjau Indonesia vs Arab Saudi: upaya menjawab keraguan" class="img-fluid lazyload" data-src="https://cdn.antaranews.com/cache/350x233/2024/11/16/Timnas-Indonesia-kalah-15112024-aaa-2.jpg" height="233px" width="350px"/>
# </picture>
# </a>
# </div>
# </div>
# <div class="col-md-7">
# <div class="card__post__body">
# <div class="card__post__content">
# <h4 class="slug"><a href="https://www.antaranews.com/slug/kualifikasi-piala-dunia-2026" title="Kualifikasi Piala Dunia 2026">Kualifikasi Piala Dunia 2026</a></h4>
# <div class="card__post__title">
# <h2 class="post_title post_title_medium"><a href="https://www.antaranews.com/berita/4475977/pratinjau-indonesia-vs-arab-saudi-upaya-menjawab-keraguan" title="Pratinjau Indonesia vs Arab Saudi: upaya menjawab keraguan">Pratinjau Indonesia vs Arab Saudi: upaya menjawab keraguan</a></h2>
# </div>
# <div class="card__post__author-info mb-2">
# <ul class="list-inline">
# <li class="list-inline-item">
# <span class="text-secondary">7 jam lalu</span>
# </li>
# </ul>
# </div>
# <p>Timnas Indonesia akan melanjutkan perjuangan dalam Kualifikasi Piala Dunia 2026 zona Asia putaran ketiga Grup C ...</p>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="card__post card__post-list card__post__transition mt-30">
# <div class="row">
# <div class="col-md-5">
# <div class="card__post__transition position-relative">
# <a href="https://www.antaranews.com/berita/4475877/kejagung-ungkap-hendry-lie-pulang-ke-indonesia-secara-diam-diam" title="Kejagung ungkap Hendry Lie pulang ke Indonesia secara diam-diam">
# <picture>
# <source data-srcset="https://cdn.antaranews.com/cache/350x233/2024/11/19/1000035594_1.jpg.webp" type="image/webp"/>
# <img alt="Kejagung ungkap Hendry Lie pulang ke Indonesia secara diam-diam" class="img-fluid lazyload" data-src="https://cdn.antaranews.com/cache/350x233/2024/11/19/1000035594_1.jpg" height="233px" width="350px"/>
# </picture>
# </a>
# </div>
# </div>
# <div class="col-md-7">
# <div class="card__post__body">
# <div class="card__post__content">
# <div class="card__post__title">
# <h2 class="post_title post_title_medium"><a href="https://www.antaranews.com/berita/4475877/kejagung-ungkap-hendry-lie-pulang-ke-indonesia-secara-diam-diam" title="Kejagung ungkap Hendry Lie pulang ke Indonesia secara diam-diam">Kejagung ungkap Hendry Lie pulang ke Indonesia secara diam-diam</a></h2>
# </div>
# <div class="card__post__author-info mb-2">
# <ul class="list-inline">
# <li class="list-inline-item">
# <span class="text-secondary">12 jam lalu</span>
# </li>
# </ul>
# </div>
# <p>Kejaksaan Agung (Kejagung) mengungkapkan bahwa tersangka kasus dugaan korupsi pengelolaan tata niaga komoditas timah di ...</p>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="card__post card__post-list card__post__transition mt-30">
# <div class="row">
# <div class="col-md-5">
# <div class="card__post__transition position-relative">
# <a href="https://www.antaranews.com/berita/4475605/kejati-tetapkan-tiga-tersangka-korupsi-pembangunan-jalan-di-bintuni" title="Kejati tetapkan tiga tersangka korupsi pembangunan jalan di Bintuni">
# <picture>
# <source data-srcset="https://cdn.antaranews.com/cache/350x233/2024/11/18/WhatsApp-Image-2024-11-18-at-20.04.20_1.jpeg.webp" type="image/webp"/>
# <img alt="Kejati tetapkan tiga tersangka korupsi pembangunan jalan di Bintuni" class="img-fluid lazyload" data-src="https://cdn.antaranews.com/cache/350x233/2024/11/18/WhatsApp-Image-2024-11-18-at-20.04.20_1.jpeg" height="233px" width="350px"/>
# </picture>
# </a>
# </div>
# </div>
# <div class="col-md-7">
# <div class="card__post__body">
# <div class="card__post__content">
# <div class="card__post__title">
# <h2 class="post_title post_title_medium"><a href="https://www.antaranews.com/berita/4475605/kejati-tetapkan-tiga-tersangka-korupsi-pembangunan-jalan-di-bintuni" title="Kejati tetapkan tiga tersangka korupsi pembangunan jalan di Bintuni">Kejati tetapkan tiga tersangka korupsi pembangunan jalan di Bintuni</a></h2>
# </div>
# <div class="card__post__author-info mb-2">
# <ul class="list-inline">
# <li class="list-inline-item">
# <span class="text-secondary">17 jam lalu</span>
# </li>
# </ul>
# </div>
# <p>Kejaksaan Tinggi (Kejati) Papua Barat menetapkan tiga tersangka pada kasus dugaan tindak pidana korupsi pembangunan ...</p>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="card__post card__post-list card__post__transition mt-30">
# <div class="row">
# <div class="col-md-5">
# <div class="card__post__transition position-relative">
# <a href="https://www.antaranews.com/berita/4475497/tiga-eks-kadis-esdm-babel-dituntut-6-hingga-7-tahun-penjara" title="Tiga eks Kadis ESDM Babel dituntut 6-hingga 7 tahun penjara">
# <picture>
# <source data-srcset="https://cdn.antaranews.com/cache/350x233/2024/11/18/1000209884_1.jpg.webp" type="image/webp"/>
# <img alt="Tiga eks Kadis ESDM Babel dituntut 6-hingga 7 tahun penjara" class="img-fluid lazyload" data-src="https://cdn.antaranews.com/cache/350x233/2024/11/18/1000209884_1.jpg" height="233px" width="350px"/>
# </picture>
# </a>
# </div>
# </div>
# <div class="col-md-7">
# <div class="card__post__body">
# <div class="card__post__content">
# <div class="card__post__title">
# <h2 class="post_title post_title_medium"><a href="https://www.antaranews.com/berita/4475497/tiga-eks-kadis-esdm-babel-dituntut-6-hingga-7-tahun-penjara" title="Tiga eks Kadis ESDM Babel dituntut 6-hingga 7 tahun penjara">Tiga eks Kadis ESDM Babel dituntut 6-hingga 7 tahun penjara</a></h2>
# </div>
# <div class="card__post__author-info mb-2">
# <ul class="list-inline">
# <li class="list-inline-item">
# <span class="text-secondary">18 jam lalu</span>
# </li>
# </ul>
# </div>
# <p>Tiga mantan Kepala Dinas (Kadis) Energi dan Sumber Daya Mineral (ESDM) Provinsi Bangka Belitung dituntut pidana penjara ...</p>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="card__post card__post-list card__post__transition mt-30">
# <div class="row">
# <div class="col-md-5">
# <div class="card__post__transition position-relative">
# <a href="https://www.antaranews.com/berita/4475417/dua-kapal-selam-koarmada-ii-latihan-geladi-tugas-tempur-iii-2024" title="Dua kapal selam Koarmada II latihan geladi tugas tempur III/2024">
# <picture>
# <source data-srcset="https://cdn.antaranews.com/cache/350x233/2024/11/18/1280D3A2-684A-4970-98EE-F9094736F8EA.jpeg.webp" type="image/webp"/>
# <img alt="Dua kapal selam Koarmada II latihan geladi tugas tempur III/2024" class="img-fluid lazyload" data-src="https://cdn.antaranews.com/cache/350x233/2024/11/18/1280D3A2-684A-4970-98EE-F9094736F8EA.jpeg" height="233px" width="350px"/>
# </picture>
# </a>
# </div>
# </div>
# <div class="col-md-7">
# <div class="card__post__body">
# <div class="card__post__content">
# <div class="card__post__title">
# <h2 class="post_title post_title_medium"><a href="https://www.antaranews.com/berita/4475417/dua-kapal-selam-koarmada-ii-latihan-geladi-tugas-tempur-iii-2024" title="Dua kapal selam Koarmada II latihan geladi tugas tempur III/2024">Dua kapal selam Koarmada II latihan geladi tugas tempur III/2024</a></h2>
# </div>
# <div class="card__post__author-info mb-2">
# <ul class="list-inline">
# <li class="list-inline-item">
# <span class="text-secondary">18 jam lalu</span>
# </li>
# </ul>
# </div>
# <p>Dua kapal selam dari Satuan Kapal Selam Komando Armada (Satsel Koarmada) II, KRI Cakra-401 dan KRI Nagapasa-403, ...</p>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="card__post card__post-list card__post__transition mt-30">
# <div class="row">
# <div class="col-md-5">
# <div class="card__post__transition position-relative">
# <a href="https://www.antaranews.com/berita/4475225/mendikdasmen-minta-guru-perhatikan-murid-tekan-kasus-bunuh-diri-remaja" title="Mendikdasmen minta guru perhatikan murid tekan kasus bunuh diri remaja">
# <picture>
# <source data-srcset="https://cdn.antaranews.com/cache/350x233/2024/11/18/1000131809_1.jpg.webp" type="image/webp"/>
# <img alt="Mendikdasmen minta guru perhatikan murid tekan kasus bunuh diri remaja" class="img-fluid lazyload" data-src="https://cdn.antaranews.com/cache/350x233/2024/11/18/1000131809_1.jpg" height="233px" width="350px"/>
# </picture>
# </a>
# </div>
# </div>
# <div class="col-md-7">
# <div class="card__post__body">
# <div class="card__post__content">
# <div class="card__post__title">
# <h2 class="post_title post_title_medium"><a href="https://www.antaranews.com/berita/4475225/mendikdasmen-minta-guru-perhatikan-murid-tekan-kasus-bunuh-diri-remaja" title="Mendikdasmen minta guru perhatikan murid tekan kasus bunuh diri remaja">Mendikdasmen minta guru perhatikan murid tekan kasus bunuh diri remaja</a></h2>
# </div>
# <div class="card__post__author-info mb-2">
# <ul class="list-inline">
# <li class="list-inline-item">
# <span class="text-secondary">19 jam lalu</span>
# </li>
# </ul>
# </div>
# <p>Menteri Pendidikan Dasar dan Menengah (Mendikdasmen), Abdul Mu'ti meminta guru untuk tidak hanya berfokus pada ...</p>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="card__post card__post-list card__post__transition mt-30">
# <div class="row">
# <div class="col-md-5">
# <div class="card__post__transition position-relative">
# <a href="https://www.antaranews.com/berita/4475193/muhammadiyah-undang-presiden-prabowo-buka-tanwir-di-kupang" title="Muhammadiyah undang Presiden Prabowo buka Tanwir di Kupang">
# <picture>
# <source data-srcset="https://cdn.antaranews.com/cache/350x233/2024/11/18/IMG_20241118_190327_1.jpg.webp" type="image/webp"/>
# <img alt="Muhammadiyah undang Presiden Prabowo buka Tanwir di Kupang" class="img-fluid lazyload" data-src="https://cdn.antaranews.com/cache/350x233/2024/11/18/IMG_20241118_190327_1.jpg" height="233px" width="350px"/>
# </picture>
# </a>
# </div>
# </div>
# <div class="col-md-7">
# <div class="card__post__body">
# <div class="card__post__content">
# <div class="card__post__title">
# <h2 class="post_title post_title_medium"><a href="https://www.antaranews.com/berita/4475193/muhammadiyah-undang-presiden-prabowo-buka-tanwir-di-kupang" title="Muhammadiyah undang Presiden Prabowo buka Tanwir di Kupang">Muhammadiyah undang Presiden Prabowo buka Tanwir di Kupang</a></h2>
# </div>
# <div class="card__post__author-info mb-2">
# <ul class="list-inline">
# <li class="list-inline-item">
# <span class="text-secondary">19 jam lalu</span>
# </li>
# </ul>
# </div>
# <p>Pimpinan Pusat (PP) Muhammadiyah mengundang Presiden RI Prabowo Subianto untuk membuka Tanwir yang akan digelar di ...</p>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="card__post card__post-list card__post__transition mt-30">
# <div class="row">
# <div class="col-md-5">
# <div class="card__post__transition position-relative">
# <a href="https://www.antaranews.com/berita/4475033/film-the-last-dance-pecahkan-rekor-box-office-hong-kong-dalam-sehari" title='Film "The Last Dance" pecahkan rekor box office Hong Kong dalam sehari'>
# <picture>
# <source data-srcset="https://cdn.antaranews.com/cache/350x233/2024/11/18/1731928782626_81i1q0_2_0_1.jpg.webp" type="image/webp"/>
# <img alt='Film "The Last Dance" pecahkan rekor box office Hong Kong dalam sehari' class="img-fluid lazyload" data-src="https://cdn.antaranews.com/cache/350x233/2024/11/18/1731928782626_81i1q0_2_0_1.jpg" height="233px" width="350px"/>
# </picture>
# </a>
# </div>
# </div>
# <div class="col-md-7">
# <div class="card__post__body">
# <div class="card__post__content">
# <div class="card__post__title">
# <h2 class="post_title post_title_medium"><a href="https://www.antaranews.com/berita/4475033/film-the-last-dance-pecahkan-rekor-box-office-hong-kong-dalam-sehari" title='Film "The Last Dance" pecahkan rekor box office Hong Kong dalam sehari'>Film "The Last Dance" pecahkan rekor box office Hong Kong dalam sehari</a></h2>
# </div>
# <div class="card__post__author-info mb-2">
# <ul class="list-inline">
# <li class="list-inline-item">
# <span class="text-secondary">20 jam lalu</span>
# </li>
# </ul>
# </div>
# <p>"The Last Dance", sebuah film drama berlatarkan rumah duka yang disutradarai oleh Anselm Chan, telah berhasil ...</p>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="card__post card__post-list card__post__transition mt-30">
# <div class="row">
# <div class="col-md-5">
# <div class="card__post__transition position-relative">
# <a href="https://www.antaranews.com/video/4474937/polresta-jayapura-kota-amankan-tiga-anggota-knpb-yang-tunggangi-demo" title="Polresta Jayapura Kota amankan tiga anggota KNPB yang tunggangi demo">
# <picture>
# <source data-srcset="https://cdn.antaranews.com/cache/350x233/2024/11/Screenshot-2024-11-18-175722.jpg.webp" type="image/webp"/>
# <img alt="Polresta Jayapura Kota amankan tiga anggota KNPB yang tunggangi demo" class="img-fluid lazyload" data-src="https://cdn.antaranews.com/cache/350x233/2024/11/Screenshot-2024-11-18-175722.jpg" height="233px" width="350px"/>
# </picture>
# </a>
# <span class="format-overlay c-overlay format-video p-center"><i class="fa fa-play"></i></span>
# </div>
# </div>
# <div class="col-md-7">
# <div class="card__post__body">
# <div class="card__post__content">
# <h4 class="slug"><a href="https://www.antaranews.com/video" title="Video">Video</a></h4>
# <div class="card__post__title">
# <h2 class="post_title post_title_medium"><a href="https://www.antaranews.com/video/4474937/polresta-jayapura-kota-amankan-tiga-anggota-knpb-yang-tunggangi-demo" title="Polresta Jayapura Kota amankan tiga anggota KNPB yang tunggangi demo">Polresta Jayapura Kota amankan tiga anggota KNPB yang tunggangi demo</a></h2>
# </div>
# <div class="card__post__author-info mb-2">
# <ul class="list-inline">
# <li class="list-inline-item">
# <span class="text-secondary">20 jam lalu</span>
# </li>
# </ul>
# </div>
# <p>ANTARA - Kepolisian Resor Jayapura Kota mengamankan tiga anggota Komite Nasional Papua Barat (KNPB) usai menunggangi ...</p>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="card__post card__post-list card__post__transition mt-30">
# <div class="row">
# <div class="col-md-5">
# <div class="card__post__transition position-relative">
# <a href="https://www.antaranews.com/berita/4474701/mensos-tegaskan-bansos-kedaruratan-tetap-disalurkan-jelang-pilkada" title="Mensos tegaskan bansos kedaruratan tetap disalurkan jelang Pilkada">
# <picture>
# <source data-srcset="https://cdn.antaranews.com/cache/350x233/2024/11/18/20241118_142038_1.jpg.webp" type="image/webp"/>
# <img alt="Mensos tegaskan bansos kedaruratan tetap disalurkan jelang Pilkada" class="img-fluid lazyload" data-src="https://cdn.antaranews.com/cache/350x233/2024/11/18/20241118_142038_1.jpg" height="233px" width="350px"/>
# </picture>
# </a>
# </div>
# </div>
# <div class="col-md-7">
# <div class="card__post__body">
# <div class="card__post__content">
# <div class="card__post__title">
# <h2 class="post_title post_title_medium"><a href="https://www.antaranews.com/berita/4474701/mensos-tegaskan-bansos-kedaruratan-tetap-disalurkan-jelang-pilkada" title="Mensos tegaskan bansos kedaruratan tetap disalurkan jelang Pilkada">Mensos tegaskan bansos kedaruratan tetap disalurkan jelang Pilkada</a></h2>
# </div>
# <div class="card__post__author-info mb-2">
# <ul class="list-inline">
# <li class="list-inline-item">
# <span class="text-secondary">21 jam lalu</span>
# </li>
# </ul>
# </div>
# <p>Menteri Sosial Saifullah Yusuf (Gus Ipul) menegaskan bantuan sosial untuk kedaruratan bencana tetap disalurkan ...</p>
# </div>
# </div>
# </div>
# </div>
# </div> </div>

# %%
results = []
for item in list_content:
  data = dict()

  # data['curr'] = item.select_one('.tb-cell').text
  # data['buy'] = item.find(attrs={"rate-type": "ERate-buy"}).text

  data['title'] = item.select_one('.card__post__title').text
  data['time'] = item.select_one('.card__post__author-info').text
  data['url'] = item.select_one('.post_title a').get('href')
  results.append(data)

pd.DataFrame(results)
# Out:
#                                                title  \
# 0  \nMenkum RI tegaskan ibu kota masih di Daerah ...
# 1                 \nHasil survei Pilgub Jawa Timur\n
# 2  \nPemimpin G20 prihatin situasi di Gaza-Lebano...
# 3  \nKasus gondongan di Indonesia masih terkendali\n
# 4  \nGibran Rakabuming Raka meninjau uji coba mak...
# 5  \nPresiden Prabowo bertemu para pemimpin MIKTA...
# 6  \nKasus gondongan di Indonesia masih terkendali\n
#
#                         time  \
# 0  \n\n\n18 menit lalu\n\n\n
# 1        \n\n23 jam lalu\n\n
# 2       \n\n6 menit lalu\n\n
# 3      \n\n28 menit lalu\n\n
# 4      \n\n10 menit lalu\n\n
# 5         \n\n2 jam lalu\n\n
# 6         \n\n1 jam lalu\n\n
#
#                                                  url
# 0  https://www.antaranews.com/berita/4476701/menk...
# 1  https://www.antaranews.com/infografik/4474241/...
# 2  https://www.antaranews.com/berita/4476729/pemi...
# 3  https://www.antaranews.com/berita/4476673/keja...
# 4  https://www.antaranews.com/foto/4476717/gibran...
# 5  https://www.antaranews.com/video/4476361/presi...
# 6  https://www.antaranews.com/infografik/4475901/...

# %% [markdown]
# # BCA - kurs IDR to xxx

# %%
url = 'https://www.bca.co.id/id/informasi/kurs'
response = requests.get(url)

# %%
soup = BeautifulSoup(response.text,'html.parser')
# soup

# %%
list_content = soup.select('.m-table-kurs') #bca kurs
# list_content = soup.select('body') #bca kurs
# list_content = soup.select('.wrapper__list__article') # antara
# list_content = soup.select('article')

# %%
len(list_content)
# Out:
# 1

# %%
list_content[0]
# list_content
# Out:
# <table class="m-table-kurs m-table--sticky-first-coloumn m-table-kurs--pad">
# <thead>
# <tr>
# <th class="pr-24 sticky-col first-col px-16" rowspan="2">
# <p class="a-text a-body-text a-text-normal-heading">Mata Uang</p>
# </th>
# <th class="pt-24" colspan="2">
# <p class="a-text a-text-body a-text-normal-heading">e-Rate <br/><span class="a-text a-text-micro color-white">20 Nov 2024 / 11.39 WIB</span></p>
# </th>
# <th class="pt-24" colspan="2">
# <p class="a-text a-text-body a-text-normal-heading">TT Counter <br/><span class="a-text a-text-micro color-white">20 Nov 2024 / 08.02 WIB</span></p>
# </th>
# <th class="pt-24" colspan="2">
# <p class="a-text a-text-body a-text-normal-heading">Bank Notes <br/><span class="a-text a-text-micro color-white">20 Nov 2024 / 08.03 WIB</span></p>
# </th>
# </tr>
# <tr>
# <td class="header">
# <p class="p-16 a-text a-text-small">Beli</p>
# </td>
# <td class="header">
# <p class="p-16 a-text a-text-small">Jual</p>
# </td>
# <td class="header">
# <p class="p-16 a-text a-text-small">Beli</p>
# </td>
# <td class="header">
# <p class="p-16 a-text a-text-small">Jual</p>
# </td>
# <td class="header">
# <p class="p-16 a-text a-text-small">Beli</p>
# </td>
# <td class="header">
# <p class="p-16 a-text a-text-small">Jual</p>
# </td>
# </tr>
# </thead>
# <tbody>
# <tr code="USD">
# <td class="sticky-col first-col">
# <span>
# <img class="icon-20" src="/-/media/Feature/Currencies/Flag/usd.png?v=1"/>
# <p class="tb-cell va-middle a-text a-text-body a-text-normal-heading py-16">USD</p>
# </span>
# </td>
# <td>
# <p class="p-16 a-text a-text-body a-text-normal-heading tb-cell va-middle" rate-type="ERate-buy">15.850,00</p>
# </td>
# <td>
# <p class="p-16 a-text a-text-body a-text-normal-heading tb-cell va-middle" rate-type="ERate-sell">15.870,00</p>
# </td>
# <td>
# <p class="p-16 a-text a-text-body a-text-normal-heading tb-cell va-middle" rate-type="TT-buy">15.690,00</p>
# </td>
# <td>
# <p class="p-16 a-text a-text-body a-text-normal-heading tb-cell va-middle" rate-type="TT-sell">15.990,00</p>
# </td>
# <td>
# <p class="p-16 a-text a-text-body a-text-normal-heading tb-cell va-middle" rate-type="BN-buy">15.690,00</p>
# </td>
# <td>
# <p class="p-16 a-text a-text-body a-text-normal-heading tb-cell va-middle" rate-type="BN-sell">15.990,00</p>
# </td>
# </tr>
# <tr code="SGD">
# <td class="sticky-col first-col">
# <span>
# <img class="icon-20" src="/-/media/Feature/Currencies/Flag/sgd.png?v=1"/>
# <p class="tb-cell va-middle a-text a-text-body a-text-normal-heading py-16">SGD</p>
# </span>
# </td>
# <td>
# <p class="p-16 a-text a-text-body a-text-normal-heading tb-cell va-middle" rate-type="ERate-buy">11.839,43</p>
# </td>
# <td>
# <p class="p-16 a-text a-text-body a-text-normal-heading tb-cell va-middle" rate-type="ERate-sell">11.852,69</p>
# </td>
# <td>
# <p class="p-16 a-text a-text-body a-text-normal-heading tb-cell va-middle" rate-type="TT-buy">11.730,20</p>
# </td>
# <td>
# <p class="p-16 a-text a-text-body a-text-normal-heading tb-cell va-middle" rate-type="TT-sell">11.963,20</p>
# </td>
# <td>
# <p class="p-16 a-text a-text-body a-text-normal-heading tb-cell va-middle" rate-type="BN-buy">11.728,00</p>
# </td>
# <td>
# <p class="p-16 a-text a-text-body a-text-normal-heading tb-cell va-middle" rate-type="BN-sell">11.962,00</p>
# </td>
# </tr>
# <tr code="EUR">
# <td class="sticky-col first-col">
# <span>
# <img class="icon-20" src="/-/media/Feature/Currencies/Flag/eur.png?v=1"/>
# <p class="tb-cell va-middle a-text a-text-body a-text-normal-heading py-16">EUR</p>
# </span>
# </td>
# <td>
# <p class="p-16 a-text a-text-body a-text-normal-heading tb-cell va-middle" rate-type="ERate-buy">16.787,86</p>
# </td>
# <td>
# <p class="p-16 a-text a-text-body a-text-normal-heading tb-cell va-middle" rate-type="ERate-sell">16.802,56</p>
# </td>
# <td>
# <p class="p-16 a-text a-text-body a-text-normal-heading tb-cell va-middle" rate-type="TT-buy">16.620,25</p>
# </td>
# <td>
# <p class="p-16 a-text a-text-body a-text-normal-heading tb-cell va-middle" rate-type="TT-sell">16.986,25</p>
# </td>
# <td>
# <p class="p-16 a-text a-text-body a-text-normal-heading tb-cell va-middle" rate-type="BN-buy">16.609,00</p>
# </td>
# <td>
# <p class="p-16 a-text a-text-body a-text-normal-heading tb-cell va-middle" rate-type="BN-sell">16.977,00</p>
# </td>
# </tr>
# <tr code="AUD">
# <td class="sticky-col first-col">
# <span>
# <img class="icon-20" src="/-/media/Feature/Currencies/Flag/aud.png?v=1"/>
# <p class="tb-cell va-middle a-text a-text-body a-text-normal-heading py-16">AUD</p>
# </span>
# </td>
# <td>
# <p class="p-16 a-text a-text-body a-text-normal-heading tb-cell va-middle" rate-type="ERate-buy">10.342,80</p>
# </td>
# <td>
# <p class="p-16 a-text a-text-body a-text-normal-heading tb-cell va-middle" rate-type="ERate-sell">10.355,43</p>
# </td>
# <td>
# <p class="p-16 a-text a-text-body a-text-normal-heading tb-cell va-middle" rate-type="TT-buy">10.226,45</p>
# </td>
# <td>
# <p class="p-16 a-text a-text-body a-text-normal-heading tb-cell va-middle" rate-type="TT-sell">10.486,45</p>
# </td>
# <td>
# <p class="p-16 a-text a-text-body a-text-normal-heading tb-cell va-middle" rate-type="BN-buy">10.226,00</p>
# </td>
# <td>
# <p class="p-16 a-text a-text-body a-text-normal-heading tb-cell va-middle" rate-type="BN-sell">10.472,00</p>
# </td>
# </tr>
# <tr code="DKK">
# <td class="sticky-col first-col">
# <span>
# <img class="icon-20" src="/-/media/Feature/Currencies/Flag/dkk.png?v=1"/>
# <p class="tb-cell va-middle a-text a-text-body a-text-normal-heading py-16">DKK</p>
# </span>
# </td>
# <td>
# <p class="p-16 a-text a-text-body a-text-normal-heading tb-cell va-middle" rate-type="ERate-buy">2.232,26</p>
# </td>
# <td>
# <p class="p-16 a-text a-text-body a-text-normal-heading tb-cell va-middle" rate-type="ERate-sell">2.270,46</p>
# </td>
# <td>
# <p class="p-16 a-text a-text-body a-text-normal-heading tb-cell va-middle" rate-type="TT-buy">2.223,85</p>
# </td>
# <td>
# <p class="p-16 a-text a-text-body a-text-normal-heading tb-cell va-middle" rate-type="TT-sell">2.288,45</p>
# </td>
# <td>
# <p class="p-16 a-text a-text-body a-text-normal-heading tb-cell va-middle" rate-type="BN-buy">0,00</p>
# </td>
# <td>
# <p class="p-16 a-text a-text-body a-text-normal-heading tb-cell va-middle" rate-type="BN-sell">0,00</p>
# </td>
# </tr>
# <tr code="SEK">
# <td class="sticky-col first-col">
# <span>
# <img class="icon-20" src="/-/media/Feature/Currencies/Flag/sek.png?v=1"/>
# <p class="tb-cell va-middle a-text a-text-body a-text-normal-heading py-16">SEK</p>
# </span>
# </td>
# <td>
# <p class="p-16 a-text a-text-body a-text-normal-heading tb-cell va-middle" rate-type="ERate-buy">1.431,50</p>
# </td>
# <td>
# <p class="p-16 a-text a-text-body a-text-normal-heading tb-cell va-middle" rate-type="ERate-sell">1.470,64</p>
# </td>
# <td>
# <p class="p-16 a-text a-text-body a-text-normal-heading tb-cell va-middle" rate-type="TT-buy">1.430,30</p>
# </td>
# <td>
# <p class="p-16 a-text a-text-body a-text-normal-heading tb-cell va-middle" rate-type="TT-sell">1.475,80</p>
# </td>
# <td>
# <p class="p-16 a-text a-text-body a-text-normal-heading tb-cell va-middle" rate-type="BN-buy">0,00</p>
# </td>
# <td>
# <p class="p-16 a-text a-text-body a-text-normal-heading tb-cell va-middle" rate-type="BN-sell">0,00</p>
# </td>
# </tr>
# <tr code="CAD">
# <td class="sticky-col first-col">
# <span>
# <img class="icon-20" src="/-/media/Feature/Currencies/Flag/cad.png?v=1"/>
# <p class="tb-cell va-middle a-text a-text-body a-text-normal-heading py-16">CAD</p>
# </span>
# </td>
# <td>
# <p class="p-16 a-text a-text-body a-text-normal-heading tb-cell va-middle" rate-type="ERate-buy">11.353,30</p>
# </td>
# <td>
# <p class="p-16 a-text a-text-body a-text-normal-heading tb-cell va-middle" rate-type="ERate-sell">11.364,80</p>
# </td>
# <td>
# <p class="p-16 a-text a-text-body a-text-normal-heading tb-cell va-middle" rate-type="TT-buy">11.218,80</p>
# </td>
# <td>
# <p class="p-16 a-text a-text-body a-text-normal-heading tb-cell va-middle" rate-type="TT-sell">11.476,80</p>
# </td>
# <td>
# <p class="p-16 a-text a-text-body a-text-normal-heading tb-cell va-middle" rate-type="BN-buy">11.216,00</p>
# </td>
# <td>
# <p class="p-16 a-text a-text-body a-text-normal-heading tb-cell va-middle" rate-type="BN-sell">11.481,00</p>
# </td>
# </tr>
# <tr code="CHF">
# <td class="sticky-col first-col">
# <span>
# <img class="icon-20" src="/-/media/Feature/Currencies/Flag/chf.png?v=1"/>
# <p class="tb-cell va-middle a-text a-text-body a-text-normal-heading py-16">CHF</p>
# </span>
# </td>
# <td>
# <p class="p-16 a-text a-text-body a-text-normal-heading tb-cell va-middle" rate-type="ERate-buy">17.940,61</p>
# </td>
# <td>
# <p class="p-16 a-text a-text-body a-text-normal-heading tb-cell va-middle" rate-type="ERate-sell">17.962,06</p>
# </td>
# <td>
# <p class="p-16 a-text a-text-body a-text-normal-heading tb-cell va-middle" rate-type="TT-buy">17.761,20</p>
# </td>
# <td>
# <p class="p-16 a-text a-text-body a-text-normal-heading tb-cell va-middle" rate-type="TT-sell">18.162,20</p>
# </td>
# <td>
# <p class="p-16 a-text a-text-body a-text-normal-heading tb-cell va-middle" rate-type="BN-buy">17.745,00</p>
# </td>
# <td>
# <p class="p-16 a-text a-text-body a-text-normal-heading tb-cell va-middle" rate-type="BN-sell">18.135,00</p>
# </td>
# </tr>
# <tr code="NZD">
# <td class="sticky-col first-col">
# <span>
# <img class="icon-20" src="/-/media/Feature/Currencies/Flag/nzd.png?v=1"/>
# <p class="tb-cell va-middle a-text a-text-body a-text-normal-heading py-16">NZD</p>
# </span>
# </td>
# <td>
# <p class="p-16 a-text a-text-body a-text-normal-heading tb-cell va-middle" rate-type="ERate-buy">9.360,88</p>
# </td>
# <td>
# <p class="p-16 a-text a-text-body a-text-normal-heading tb-cell va-middle" rate-type="ERate-sell">9.373,95</p>
# </td>
# <td>
# <p class="p-16 a-text a-text-body a-text-normal-heading tb-cell va-middle" rate-type="TT-buy">9.233,15</p>
# </td>
# <td>
# <p class="p-16 a-text a-text-body a-text-normal-heading tb-cell va-middle" rate-type="TT-sell">9.506,15</p>
# </td>
# <td>
# <p class="p-16 a-text a-text-body a-text-normal-heading tb-cell va-middle" rate-type="BN-buy">9.255,00</p>
# </td>
# <td>
# <p class="p-16 a-text a-text-body a-text-normal-heading tb-cell va-middle" rate-type="BN-sell">9.483,00</p>
# </td>
# </tr>
# <tr code="GBP">
# <td class="sticky-col first-col">
# <span>
# <img class="icon-20" src="/-/media/Feature/Currencies/Flag/gbp.png?v=1"/>
# <p class="tb-cell va-middle a-text a-text-body a-text-normal-heading py-16">GBP</p>
# </span>
# </td>
# <td>
# <p class="p-16 a-text a-text-body a-text-normal-heading tb-cell va-middle" rate-type="ERate-buy">20.105,72</p>
# </td>
# <td>
# <p class="p-16 a-text a-text-body a-text-normal-heading tb-cell va-middle" rate-type="ERate-sell">20.128,25</p>
# </td>
# <td>
# <p class="p-16 a-text a-text-body a-text-normal-heading tb-cell va-middle" rate-type="TT-buy">19.879,40</p>
# </td>
# <td>
# <p class="p-16 a-text a-text-body a-text-normal-heading tb-cell va-middle" rate-type="TT-sell">20.329,40</p>
# </td>
# <td>
# <p class="p-16 a-text a-text-body a-text-normal-heading tb-cell va-middle" rate-type="BN-buy">19.880,00</p>
# </td>
# <td>
# <p class="p-16 a-text a-text-body a-text-normal-heading tb-cell va-middle" rate-type="BN-sell">20.311,00</p>
# </td>
# </tr>
# <tr code="HKD">
# <td class="sticky-col first-col">
# <span>
# <img class="icon-20" src="/-/media/Feature/Currencies/Flag/hkd.png?v=1"/>
# <p class="tb-cell va-middle a-text a-text-body a-text-normal-heading py-16">HKD</p>
# </span>
# </td>
# <td>
# <p class="p-16 a-text a-text-body a-text-normal-heading tb-cell va-middle" rate-type="ERate-buy">2.033,70</p>
# </td>
# <td>
# <p class="p-16 a-text a-text-body a-text-normal-heading tb-cell va-middle" rate-type="ERate-sell">2.041,74</p>
# </td>
# <td>
# <p class="p-16 a-text a-text-body a-text-normal-heading tb-cell va-middle" rate-type="TT-buy">2.005,20</p>
# </td>
# <td>
# <p class="p-16 a-text a-text-body a-text-normal-heading tb-cell va-middle" rate-type="TT-sell">2.065,10</p>
# </td>
# <td>
# <p class="p-16 a-text a-text-body a-text-normal-heading tb-cell va-middle" rate-type="BN-buy">2.010,00</p>
# </td>
# <td>
# <p class="p-16 a-text a-text-body a-text-normal-heading tb-cell va-middle" rate-type="BN-sell">2.059,00</p>
# </td>
# </tr>
# <tr code="JPY">
# <td class="sticky-col first-col">
# <span>
# <img class="icon-20" src="/-/media/Feature/Currencies/Flag/jpy.png?v=1"/>
# <p class="tb-cell va-middle a-text a-text-body a-text-normal-heading py-16">JPY</p>
# </span>
# </td>
# <td>
# <p class="p-16 a-text a-text-body a-text-normal-heading tb-cell va-middle" rate-type="ERate-buy">102,23</p>
# </td>
# <td>
# <p class="p-16 a-text a-text-body a-text-normal-heading tb-cell va-middle" rate-type="ERate-sell">102,33</p>
# </td>
# <td>
# <p class="p-16 a-text a-text-body a-text-normal-heading tb-cell va-middle" rate-type="TT-buy">100,80</p>
# </td>
# <td>
# <p class="p-16 a-text a-text-body a-text-normal-heading tb-cell va-middle" rate-type="TT-sell">103,84</p>
# </td>
# <td>
# <p class="p-16 a-text a-text-body a-text-normal-heading tb-cell va-middle" rate-type="BN-buy">100,30</p>
# </td>
# <td>
# <p class="p-16 a-text a-text-body a-text-normal-heading tb-cell va-middle" rate-type="BN-sell">104,24</p>
# </td>
# </tr>
# <tr code="SAR">
# <td class="sticky-col first-col">
# <span>
# <img class="icon-20" src="/-/media/Feature/Currencies/Flag/sar-benar.png?v=1"/>
# <p class="tb-cell va-middle a-text a-text-body a-text-normal-heading py-16">SAR</p>
# </span>
# </td>
# <td>
# <p class="p-16 a-text a-text-body a-text-normal-heading tb-cell va-middle" rate-type="ERate-buy">4.221,07</p>
# </td>
# <td>
# <p class="p-16 a-text a-text-body a-text-normal-heading tb-cell va-middle" rate-type="ERate-sell">4.228,09</p>
# </td>
# <td>
# <p class="p-16 a-text a-text-body a-text-normal-heading tb-cell va-middle" rate-type="TT-buy">4.166,35</p>
# </td>
# <td>
# <p class="p-16 a-text a-text-body a-text-normal-heading tb-cell va-middle" rate-type="TT-sell">4.273,35</p>
# </td>
# <td>
# <p class="p-16 a-text a-text-body a-text-normal-heading tb-cell va-middle" rate-type="BN-buy">4.129,00</p>
# </td>
# <td>
# <p class="p-16 a-text a-text-body a-text-normal-heading tb-cell va-middle" rate-type="BN-sell">4.284,00</p>
# </td>
# </tr>
# <tr code="CNY">
# <td class="sticky-col first-col">
# <span>
# <img class="icon-20" src="/-/media/Feature/Currencies/Flag/cnh.png?v=1"/>
# <p class="tb-cell va-middle a-text a-text-body a-text-normal-heading py-16">CNH</p>
# </span>
# </td>
# <td>
# <p class="p-16 a-text a-text-body a-text-normal-heading tb-cell va-middle" rate-type="ERate-buy">2.184,51</p>
# </td>
# <td>
# <p class="p-16 a-text a-text-body a-text-normal-heading tb-cell va-middle" rate-type="ERate-sell">2.194,44</p>
# </td>
# <td>
# <p class="p-16 a-text a-text-body a-text-normal-heading tb-cell va-middle" rate-type="TT-buy">2.108,90</p>
# </td>
# <td>
# <p class="p-16 a-text a-text-body a-text-normal-heading tb-cell va-middle" rate-type="TT-sell">2.272,00</p>
# </td>
# <td>
# <p class="p-16 a-text a-text-body a-text-normal-heading tb-cell va-middle" rate-type="BN-buy">2.129,00</p>
# </td>
# <td>
# <p class="p-16 a-text a-text-body a-text-normal-heading tb-cell va-middle" rate-type="BN-sell">2.245,00</p>
# </td>
# </tr>
# <tr code="MYR">
# <td class="sticky-col first-col">
# <span>
# <img class="icon-20" src="/-/media/Feature/Currencies/Flag/myr.png?v=1"/>
# <p class="tb-cell va-middle a-text a-text-body a-text-normal-heading py-16">MYR</p>
# </span>
# </td>
# <td>
# <p class="p-16 a-text a-text-body a-text-normal-heading tb-cell va-middle" rate-type="ERate-buy">3.540,39</p>
# </td>
# <td>
# <p class="p-16 a-text a-text-body a-text-normal-heading tb-cell va-middle" rate-type="ERate-sell">3.556,38</p>
# </td>
# <td>
# <p class="p-16 a-text a-text-body a-text-normal-heading tb-cell va-middle" rate-type="TT-buy">3.498,55</p>
# </td>
# <td>
# <p class="p-16 a-text a-text-body a-text-normal-heading tb-cell va-middle" rate-type="TT-sell">3.589,55</p>
# </td>
# <td>
# <p class="p-16 a-text a-text-body a-text-normal-heading tb-cell va-middle" rate-type="BN-buy">0,00</p>
# </td>
# <td>
# <p class="p-16 a-text a-text-body a-text-normal-heading tb-cell va-middle" rate-type="BN-sell">0,00</p>
# </td>
# </tr>
# <tr code="THB">
# <td class="sticky-col first-col">
# <span>
# <img class="icon-20" src="/-/media/Feature/Currencies/Flag/thb.png?v=1"/>
# <p class="tb-cell va-middle a-text a-text-body a-text-normal-heading py-16">THB</p>
# </span>
# </td>
# <td>
# <p class="p-16 a-text a-text-body a-text-normal-heading tb-cell va-middle" rate-type="ERate-buy">458,27</p>
# </td>
# <td>
# <p class="p-16 a-text a-text-body a-text-normal-heading tb-cell va-middle" rate-type="ERate-sell">458,99</p>
# </td>
# <td>
# <p class="p-16 a-text a-text-body a-text-normal-heading tb-cell va-middle" rate-type="TT-buy">454,75</p>
# </td>
# <td>
# <p class="p-16 a-text a-text-body a-text-normal-heading tb-cell va-middle" rate-type="TT-sell">463,75</p>
# </td>
# <td>
# <p class="p-16 a-text a-text-body a-text-normal-heading tb-cell va-middle" rate-type="BN-buy">429,00</p>
# </td>
# <td>
# <p class="p-16 a-text a-text-body a-text-normal-heading tb-cell va-middle" rate-type="BN-sell">488,00</p>
# </td>
# </tr>
# </tbody>
# </table>

# %%
table = soup.find('table', class_ = 'm-table-kurs')
# print(table)

results = []
for employee_data in table.find_all('tbody'):
  rows = employee_data.find_all('tr')
  # print(rows)

  for row in rows:
    # name = row.find_all('td')[0].text
    # print(name)

    data = dict()
    data['curr'] = row.find_all('td')[0].text
    data['buy'] = row.find_all('td')[1].text
    data['sell'] = row.find_all('td')[2].text

    results.append(data)

pd.DataFrame(results)
# Out:
#              curr            buy           sell
# 0   \n\n\nUSD\n\n  \n15.850,00\n  \n15.870,00\n
# 1   \n\n\nSGD\n\n  \n11.839,43\n  \n11.852,69\n
# 2   \n\n\nEUR\n\n  \n16.787,86\n  \n16.802,56\n
# 3   \n\n\nAUD\n\n  \n10.342,80\n  \n10.355,43\n
# 4   \n\n\nDKK\n\n   \n2.232,26\n   \n2.270,46\n
# 5   \n\n\nSEK\n\n   \n1.431,50\n   \n1.470,64\n
# 6   \n\n\nCAD\n\n  \n11.353,30\n  \n11.364,80\n
# 7   \n\n\nCHF\n\n  \n17.940,61\n  \n17.962,06\n
# 8   \n\n\nNZD\n\n   \n9.360,88\n   \n9.373,95\n
# 9   \n\n\nGBP\n\n  \n20.105,72\n  \n20.128,25\n
# 10  \n\n\nHKD\n\n   \n2.033,70\n   \n2.041,74\n
# 11  \n\n\nJPY\n\n     \n102,23\n     \n102,33\n
# 12  \n\n\nSAR\n\n   \n4.221,07\n   \n4.228,09\n
# 13  \n\n\nCNH\n\n   \n2.184,51\n   \n2.194,44\n
# 14  \n\n\nMYR\n\n   \n3.540,39\n   \n3.556,38\n
# 15  \n\n\nTHB\n\n     \n458,27\n     \n458,99\n

# %% [markdown]
# # Save to CSV

# %%
import pandas as pd
from google.colab import drive

drive.mount('drive')

# Membuat DataFrame dari data
df = pd.DataFrame(results)

# Menyimpan DataFrame ke file CSV
# df.to_csv('data.csv', index=False)  # `index=False` untuk tidak menyertakan indeks
# df.to_csv('C:/Users/arifin.ajinusa/Downloads/data.csv', index=False)  # Contoh untuk Windows
df.to_csv('/content/drive/My Drive/DiBimbing Aji/kurs IDR.csv', index=False)
print("Data berhasil diekspor")




# df.to_csv('data.csv')
# !cp data.csv "drive/My Drive/"
# Out:
# Mounted at drive
# Data berhasil diekspor
